# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%time
from qplanarity import test_suite

times = [2.1, 1.6]
pulses = [0.2, 0.1]

generator = 'binomial'
metric = 'f1-score'
test_big = False
test_ramping_max_n = None

train_ns = range(3, 11)
train_nbs = 2 * [50] + 3 * [100] + 3 * [200]

test_ns = list(range(3, 21))
test_nbs = [500] * 8 + [300] * 5 + [150] * 3 + [100] * 2
test_ns = test_ns[:-9]
test_nbs = list(map(int, np.array(test_nbs)))[:-9]

all_results = test_suite(times, pulses, train_ns, train_nbs, generator, seed=12, metric=metric, 
                 test_ns=test_ns, test_nbs=test_nbs, test_smoke=False, test_big=test_big, test_ramping_max_n=test_ramping_max_n,
                return_all=True)
# Out:
# 	# 1. Generate train dataset
# 0it [00:00, ?it/s]
# Generated graphs with   3 nodes are at 100.0% planar in average
# Generated graphs with   4 nodes are at 100.0% planar in average
# Generated graphs with   5 nodes are at  88.0% planar in average
# Generated graphs with   6 nodes are at  76.0% planar in average
# Generated graphs with   7 nodes are at  48.0% planar in average
# Generated graphs with   8 nodes are at  53.0% planar in average
# Generated graphs with   9 nodes are at  37.5% planar in average
# Generated graphs with  10 nodes are at  35.0% planar in average
# Generated graphs are at  56.3% planar in average
#
# 	# 2. Train model
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# /Users/romainfouilland/.pyenv/versions/3.8.3/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass n_splits=10, n_repeats=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# Accuracy: 96.000% ± 2.010% for C=100.0
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=10, n_splits=10, random_state=47),
#              estimator=SVC(kernel='precomputed', random_state=76), n_jobs=-1,
#              param_grid={'C': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])},
#              refit='accuracy',
#              scoring={'accuracy': make_scorer(accuracy_score),
#                       'f1_score': make_scorer(f1_score, average=weighted)})
#
# 	# 3. Smoke-test model
#
# Skipped
#
# 	# 4. Investigate capabilities
#
#
# 	#   - Test set [3, 4, 5, 6, 7, 8, 9, 10, 11] nodes in numbers [500, 500, 500, 500, 500, 500, 500, 500, 300]
#   0%|          | 0/4300 [00:00<?, ?it/s]
#   0%|          | 0/4300 [00:00<?, ?it/s]
# dist1 loop:   0%|          | 0/4300 [00:00<?, ?it/s]
# [[1339   79]
#  [  68 2814]]
#               precision    recall  f1-score   support
#
#   Non-planar       0.95      0.94      0.95      1418
#       Planar       0.97      0.98      0.97      2882
#
#     accuracy                           0.97      4300
#    macro avg       0.96      0.96      0.96      4300
# weighted avg       0.97      0.97      0.97      4300
#
#
# 	### Score: 96.58% (f1-score for planar: 0.975 & non-planar: 0.948)
# CPU times: user 2min 10s, sys: 1.58 s, total: 2min 12s
# Wall time: 2min 12s

# %%
# Update with return_all to see how it scores for each + add histograms on nb trained for each nb od nodes & nb predicts (with 2 colors for planar & not + 2 colors for correct or not)

# %%
from qplanarity import results_graph
results_graph(all_results, train_nbs, train_ns, test_nbs, test_ns, '3->10')
# Out:
# 4300 4300 1000

# %%
confusion_matrix([0, 0], [0, 1])
# Out:
# array([[1, 1],
#        [0, 0]])

# %%
len(test_ns), len(test_nbs)
# Out:
# (18, 18)

# %%
np.array(cms)[:,0, 0]
# Out:
# array([  0,   0, 110, 166, 261, 208, 232, 247, 178, 183, 178, 199, 217,
#        107, 123, 128,  88,  81])

# %%
np.sum(np.sum(cms, axis=1), axis=1)
# Out:
# array([500, 500, 500, 500, 500, 500, 500, 500, 300, 300, 300, 300, 300,
#        150, 150, 150, 100, 100])

# %%
train_planars, train_non_planars
# Out:
# ([50, 50, 72, 64, 50, 128, 107, 93], [0, 0, 28, 36, 50, 72, 93, 107])

# %%
test_planars, test_non_planars
# Out:
# ([500,
#   500,
#   390,
#   334,
#   237,
#   290,
#   268,
#   253,
#   120,
#   117,
#   122,
#   99,
#   83,
#   36,
#   27,
#   22,
#   12,
#   19],
#  [0,
#   0,
#   110,
#   166,
#   263,
#   210,
#   232,
#   247,
#   180,
#   183,
#   178,
#   201,
#   217,
#   114,
#   123,
#   128,
#   88,
#   81])

# %%
train_planars / np.array(train_nbs)
# Out:
# array([1.   , 1.   , 0.72 , 0.64 , 0.5  , 0.64 , 0.535, 0.465])

# %%
np.arange(0.8, 1.001, 0.025)
# Out:
# array([0.8  , 0.825, 0.85 , 0.875, 0.9  , 0.925, 0.95 , 0.975, 1.   ])
